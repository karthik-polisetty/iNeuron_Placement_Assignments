# %% [markdown]
# Q9. Write a program to read the data from the following link, perform data analysis and answer the following
# questions
#
# Note -
# 1. Write code comments wherever required for code understanding
#
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
#
# Insights to be drawn
# - Get all the cars and their types that do not qualify for clean alternative fuel vehicle
# - Get all TESLA cars with the model year, and model type made in Bothell City.
# - Get all the cars that have an electric range of more than 100, and were made after
#     2015
# - Draw plots to show the distribution between city and electric vehicle type

# %%
import pandas as pd
df= pd.read_csv('https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD')

# %%
df.head(1)
# Out:
#    VIN (1-10)  County    City State  Postal Code  Model Year   Make    Model  \
# 0  5YJXCAE26J  Yakima  Yakima    WA      98908.0        2018  TESLA  MODEL X
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  14.0       141151601
#
#               Vehicle Location Electric Utility  2020 Census Tract
# 0  POINT (-120.56916 46.58514)       PACIFICORP       5.307700e+10

# %% [markdown]
# ### Get all the cars and their types that do not qualify for clean alternative fuel vehicle

# %%
df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility']=='Not eligible due to low battery range'][['Make','Model']]
# Out:
#           Make        Model
# 6         FORD       FUSION
# 7         AUDI         Q5 E
# 8         FORD        C-MAX
# 14        FORD        C-MAX
# 15         KIA         NIRO
# ...        ...          ...
# 130377     BMW         530E
# 130385    AUDI           A3
# 130390    JEEP     WRANGLER
# 130407  TOYOTA  PRIUS PRIME
# 130437     BMW         530E
#
# [16446 rows x 2 columns]

# %% [markdown]
# ### Get all TESLA cars with the model year, and model type made in Bothell City.

# %%
df[(df['City']=='Bothell') & (df['Make']=='TESLA')][['Model Year','Model']]
# Out:
#         Model Year    Model
# 39            2020  MODEL 3
# 217           2022  MODEL 3
# 218           2022  MODEL Y
# 222           2018  MODEL 3
# 292           2017  MODEL X
# ...            ...      ...
# 129778        2019  MODEL 3
# 129954        2021  MODEL 3
# 129976        2014  MODEL S
# 130295        2022  MODEL 3
# 130392        2018  MODEL 3
#
# [2407 rows x 2 columns]

# %% [markdown]
# ### Get all the cars that have an electric range of more than 100, and were made after 2015

# %%
df[(df['Electric Range']>100)&(df['Model Year']>2015)]
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %% [markdown]
# ### Draw plots to show the distribution between city and electric vehicle type

# %%
df.head(1)
# Out:
#    VIN (1-10)  County    City State  Postal Code  Model Year   Make    Model  \
# 0  5YJXCAE26J  Yakima  Yakima    WA      98908.0        2018  TESLA  MODEL X
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  14.0       141151601
#
#               Vehicle Location Electric Utility  2020 Census Tract
# 0  POINT (-120.56916 46.58514)       PACIFICORP       5.307700e+10

# %%
df['City'].nunique()
# Out:
# 656

# %%
df['Electric Vehicle Type'].value_counts()
# Out:
# Battery Electric Vehicle (BEV)            100156
# Plug-in Hybrid Electric Vehicle (PHEV)     30287
# Name: Electric Vehicle Type, dtype: int64

# %%
df[df['City']=='Yakima']['Electric Vehicle Type'].value_counts()
# Out:
# Battery Electric Vehicle (BEV)            309
# Plug-in Hybrid Electric Vehicle (PHEV)    162
# Name: Electric Vehicle Type, dtype: int64
